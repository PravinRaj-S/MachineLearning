# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("canada_per_capita_income.csv")
df.head()
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
plt.figure(figsize=(12,6))
plt.scatter(df.year, df.income, marker='+', c='red')
plt.xlabel("Year")
plt.ylabel("Per Capita Income in Us$")
plt.title("Canada Per Capita Income")
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df.income)
# Out:
# LinearRegression()

# %%
plt.figure(figsize=(12,6))
plt.scatter(df.year, df.income, marker='+', c='red')
plt.xlabel("Year")
plt.ylabel("Per Capita Income in Us$")
plt.title("Canada Per Capita Income")
plt.plot(df.year, reg.predict(df[['year']]), color='blue')
plt.show()

# %%
reg.predict([[2024]])

# https://data.worldbank.org/indicator/NY.ADJ.NNTY.PC.CD?locations=CA refer this website for check prediction
# Out:
# c:\Users\pravinraj.selvaraj\anaconda3\envs\MachineLearning\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([44602.55439531])
